# %% [markdown]
# <a href="https://colab.research.google.com/github/shin8322/CL_ML/blob/main/LSIT_RBC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
data = np.array([1, 2, 3])
print(data * 2)

print("Hello, World!")
# Out:
# [2 4 6]
# Hello, World!
